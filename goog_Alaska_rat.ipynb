# %%
import pandas as pd
import numpy as np
import json

# %%
archivo_json = '4.json'

# Se inicializa una lista para almacenar los objetos JSON
data = []

# Se lee el archivo JSON línea por línea y carga cada objeto JSON
with open(archivo_json, 'r') as archivo:
    for linea in archivo:
        objeto_json = json.loads(linea)
        data.append(objeto_json)

# Convierte la lista de objetos JSON en un DataFrame
df_goog_alaska01 = pd.DataFrame(data)

# %%
df_goog_alaska01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71515 entries, 0 to 71514
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  71515 non-null  object
#  1   name     71515 non-null  object
#  2   time     71515 non-null  int64
#  3   rating   71515 non-null  int64
#  4   text     39932 non-null  object
#  5   pics     3735 non-null   object
#  6   resp     3983 non-null   object
#  7   gmap_id  71515 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 4.4+ MB

# %%
# Filtrar los registros con rating 5
df_5 = df_goog_alaska01[df_goog_alaska01['rating'] == 5]

# %%
df_5.head()
# Out:
#                  user_id              name           time  rating  \
# 0  113578699778021752958  Shirley Beaudoin  1528750288672       5
# 1  106731689968809847217      Jason Rootes  1482527691553       5
# 3  112593679290274864872      Bill Kennedy  1575437871415       5
# 4  105777237010587506925                 T  1472451047251       5
# 8  103208919196601261371             Tanya  1531997778280       5
#
#                                                 text  pics  \
# 0                        So good,I enjoyed our lunch  None
# 1  Great breakfast, great service.  Never-ending ...  None
# 3                               Great bar for MNF!!!  None
# 4  Great service and attentive staff, I had a min...  None
# 8             Love the deck and draft beer selection  None
#
#                                                 resp  \
# 0                                               None
# 1                                               None
# ...

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40933 entries, 0 to 71514
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  40933 non-null  object
#  1   name     40933 non-null  object
#  2   time     40933 non-null  int64
#  3   rating   40933 non-null  int64
#  4   text     23473 non-null  object
#  5   pics     2740 non-null   object
#  6   resp     2200 non-null   object
#  7   gmap_id  40933 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 2.8+ MB

# %%
# Obtener una lista de valores únicos en la columna 'name'
unique_names = df_5['name'].unique()

# Calcular la longitud de la lista de valores únicos
len_unique_names = len(unique_names)

# Imprimir la lista de valores únicos y su longitud
print("Valores únicos en 'name':", unique_names)
print("Longitud de la lista de valores únicos:", len_unique_names)
# Out:
# Valores únicos en 'name': ['Shirley Beaudoin' 'Jason Rootes' 'Bill Kennedy' ... 'Dan Justice'
#  'Loves2Jacket' 'Ossie Knowlton']
# Longitud de la lista de valores únicos: 14033

# %%
# Obtener una lista de valores únicos en la columna 'name'
unique_locs = df_5['gmap_id'].unique()

# Calcular la longitud de la lista de valores únicos
len_unique_locs = len(unique_locs)

# Imprimir la lista de valores únicos y su longitud
print("Valores únicos en 'gmap_id':", unique_locs)
print("Longitud de la lista de valores únicos en 'gmap_id':", len_unique_names)
# Out:
# Valores únicos en 'gmap_id': ['0x56dabba05e6f24f3:0xba883b7b879a177d'
#  '0x56c899d7905cde13:0x97654a7c0628bcad'
#  '0x56c897c63697ee39:0x419904ababbc740b'
#  '0x56c897cfd8f68609:0xcc09175e6bbf8aad'
#  '0x56c897bc4139725d:0x65383efe52f652fe'
#  '0x56c899d09c6ae63b:0x7fed45948988e5df'
#  '0x56c89629c34ac1a1:0x5bf358c64d144015'
#  '0x56c899d31bcd7975:0xb5294821db7249c5'
#  '0x56c897be1dc0358d:0x4590989785839cb4'
#  '0x56c897cb5c9b2297:0xbb6eb5e2d68529db'
#  '0x56c899d26513cef1:0x34929bee90dcfc06'
#  '0x56e73decc8e7920f:0xbda1c2ba01e35d0d'
#  '0x56c896ef55bf7f0d:0x7525b23defe36b8f'
#  '0x56c897c52ddf8317:0x860a8e5f5b2cfb22'
#  '0x56c897dcf3a6ad61:0xca19b1ecc07f0743'
#  '0x56c897e85016d27b:0x8e9b8e1e6d03513a'
#  '0x56c897cfdf3f752b:0x95a8e6813f8350b'
#  '0x56c899d8e705dbcf:0xadaf25836851f355'
#  '0x56c8bd876b835871:0xa83694c07c2a3555'
#  '0x56c899dae2696475:0x2528663f168091fe'
#  '0x50c2d8079814f081:0xb5872304158b4945'
#  '0x50c2d8079814f081:0xa05d2dbbab2b2a73'
# ...
